# %%
import pandas as pd;
import matplotlib.pyplot as plt
import numpy as np;

# %%
covidcountry=pd.read_csv(r'D:\covid analysyis\country_wise_latest.csv')

# %%
covicountry.head(10)
# Out:
#         Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0          Afghanistan      36263    1269      25198    9796        106
# 1              Albania       4880     144       2745    1991        117
# 2              Algeria      27973    1163      18837    7973        616
# 3              Andorra        907      52        803      52         10
# 4               Angola        950      41        242     667         18
# 5  Antigua and Barbuda         86       3         65      18          4
# 6            Argentina     167416    3059      72575   91782       4890
# 7              Armenia      37390     711      26665   10014         73
# 8            Australia      15303     167       9311    5825        368
# 9              Austria      20558     713      18246    1599         86
#
#    New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0          10             18                3.50                  69.49
# ...

# %%
covicountry.head(10)
# Out:
# 0     106
# 1     117
# 2     616
# 3      10
# 4      18
# 5       4
# 6    4890
# 7      73
# 8     368
# 9      86
# Name: New cases, dtype: int64

# %%
covicountry
# Out:
# 0      106
# 1      117
# 2      616
# 3       10
# 4       18
#       ...
# 182    152
# 183      0
# 184     10
# 185     71
# 186    192
# Name: New cases, Length: 187, dtype: int64

# %%
covidcountry.head(10)
# Out:
#         Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0          Afghanistan      36263    1269      25198    9796        106
# 1              Albania       4880     144       2745    1991        117
# 2              Algeria      27973    1163      18837    7973        616
# 3              Andorra        907      52        803      52         10
# 4               Angola        950      41        242     667         18
# 5  Antigua and Barbuda         86       3         65      18          4
# 6            Argentina     167416    3059      72575   91782       4890
# 7              Armenia      37390     711      26665   10014         73
# 8            Australia      15303     167       9311    5825        368
# 9              Austria      20558     713      18246    1599         86
#
#    New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0          10             18                3.50                  69.49
# ...

# %%
covidcountry.drop(["New cases","New deaths","New recovered"],inplace=True,axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 covidcountry.drop(["New cases","New deaths","New recovered"],inplace=True,axis=1)
#
# NameError: name 'covidcountry' is not defined

# %%
covidcountry.head(10)
# Out:
#                Country  Confirmed  Deaths  Recovered  Active  New cases  \
# 0          Afghanistan      36263    1269      25198    9796        106
# 1              Albania       4880     144       2745    1991        117
# 2              Algeria      27973    1163      18837    7973        616
# 3              Andorra        907      52        803      52         10
# 4               Angola        950      41        242     667         18
# 5  Antigua and Barbuda         86       3         65      18          4
# 6            Argentina     167416    3059      72575   91782       4890
# 7              Armenia      37390     711      26665   10014         73
# 8            Australia      15303     167       9311    5825        368
# 9              Austria      20558     713      18246    1599         86
#
#    New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0          10             18                3.50                  69.49
# ...

# %%
covidcountry.drop(["1 week change"],inplace=True,axis=1)

# %%
covidcountry.head(10)
# Out:
#                Country  Confirmed  Deaths  Recovered  Active  New cases  \
# 0          Afghanistan      36263    1269      25198    9796        106
# 1              Albania       4880     144       2745    1991        117
# 2              Algeria      27973    1163      18837    7973        616
# 3              Andorra        907      52        803      52         10
# 4               Angola        950      41        242     667         18
# 5  Antigua and Barbuda         86       3         65      18          4
# 6            Argentina     167416    3059      72575   91782       4890
# 7              Armenia      37390     711      26665   10014         73
# 8            Australia      15303     167       9311    5825        368
# 9              Austria      20558     713      18246    1599         86
#
#    New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0          10             18                3.50                  69.49
# ...

# %%
sorted=covidcountry.sort_values('Deaths',ascending=False)

# %%
sorted
# Out:
#      Country/Region  Confirmed  Deaths  Recovered   Active  \
# 173              US    4290259  148011    1325804  2816444
# 23           Brazil    2442375   87618    1846641   508116
# 177  United Kingdom     301708   45844       1437   254427
# 111          Mexico     395489   44022     303810    47657
# 85            Italy     246286   35112     198593    12581
# ..              ...        ...     ...        ...      ...
# 94             Laos         20       0         19        1
# 68        Greenland         14       0         13        1
# 30         Cambodia        226       0        147       79
# 69          Grenada         23       0         23        0
# 114        Mongolia        289       0        222       67
#
#      Deaths / 100 Cases  Recovered / 100 Cases  Deaths / 100 Recovered  \
# 173                3.45                  30.90                   11.16
# 23                 3.59                  75.61                    4.74
# ...

# %%
bar
# Out:
#                Country  Confirmed  Deaths  Recovered  Active  New cases  \
# 0          Afghanistan      36263    1269      25198    9796        106
# 1              Albania       4880     144       2745    1991        117
# 2              Algeria      27973    1163      18837    7973        616
# 3              Andorra        907      52        803      52         10
# 4               Angola        950      41        242     667         18
# 5  Antigua and Barbuda         86       3         65      18          4
# 6            Argentina     167416    3059      72575   91782       4890
# 7              Armenia      37390     711      26665   10014         73
# 8            Australia      15303     167       9311    5825        368
# 9              Austria      20558     713      18246    1599         86
#
#    New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0          10             18                3.50                  69.49
# ...

# %%
plt.barh(bar.Country,bar.Deaths)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sorted1=covidcountry.sort_values('Deaths',ascending=False)

# %%
sorted1
# Out:
#             Country  Confirmed  Deaths  Recovered   Active  New cases  \
# 173              US    4290259  148011    1325804  2816444      56336
# 23           Brazil    2442375   87618    1846641   508116      23284
# 177  United Kingdom     301708   45844       1437   254427        688
# 111          Mexico     395489   44022     303810    47657       4973
# 85            Italy     246286   35112     198593    12581        168
# ..              ...        ...     ...        ...      ...        ...
# 94             Laos         20       0         19        1          0
# 68        Greenland         14       0         13        1          1
# 30         Cambodia        226       0        147       79          1
# 69          Grenada         23       0         23        0          0
# 114        Mongolia        289       0        222       67          1
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
sorted1=sorted1.head(10)

# %%
plt.barh(sorted1.Country,sorted1.Deaths)
plt.ylabel("Countries")
plt.xlabel("No of deaths")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
piechart=sorted1.head(5);

# %%
piechart
# Out:
#             Country  Confirmed  Deaths  Recovered   Active  New cases  \
# 173              US    4290259  148011    1325804  2816444      56336
# 23           Brazil    2442375   87618    1846641   508116      23284
# 177  United Kingdom     301708   45844       1437   254427        688
# 111          Mexico     395489   44022     303810    47657       4973
# 85            Italy     246286   35112     198593    12581        168
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 173        1076          27941                3.45                  30.90
# 23          614          33728                3.59                  75.61
# 177           7              3               15.19                   0.48
# 111         342           8588               11.13                  76.82
# 85            5            147               14.26                  80.64
#
#      Deaths / 100 Recovered  Confirmed last week  1 week change  \
# ...

# %%
plt.pie(piechart.Confirmed,labels=piechart.Country)
plt.title("Active cases")
# Out:
# Text(0.5, 1.0, 'Active cases')

# %%
piechart
# Out:
#             Country  Confirmed  Deaths  Recovered   Active  New cases  \
# 173              US    4290259  148011    1325804  2816444      56336
# 23           Brazil    2442375   87618    1846641   508116      23284
# 177  United Kingdom     301708   45844       1437   254427        688
# 111          Mexico     395489   44022     303810    47657       4973
# 85            Italy     246286   35112     198593    12581        168
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 173        1076          27941                3.45                  30.90
# 23          614          33728                3.59                  75.61
# 177           7              3               15.19                   0.48
# 111         342           8588               11.13                  76.82
# 85            5            147               14.26                  80.64
#
#      Deaths / 100 Recovered  Confirmed last week  1 week change  \
# ...

# %%
plt.plot(piechart.Deaths)

# %%
plt.bar(piechart.Country,piechart.Recovered)
plt.xlabel("Country")
plt.ylabel("Recovered")
# Out:
# Text(0, 0.5, 'Recovered')

# %%
vaccination=pd.read_csv("D:\covid analysyis\country_vaccinations.csv");

# %%
vaccination.head(10)
# Out:
#        country iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG  2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG  2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG  2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG  2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG  2021-02-26                 NaN                NaN
# 5  Afghanistan      AFG  2021-02-27                 NaN                NaN
# 6  Afghanistan      AFG  2021-02-28              8200.0             8200.0
# 7  Afghanistan      AFG  2021-03-01                 NaN                NaN
# 8  Afghanistan      AFG  2021-03-02                 NaN                NaN
# 9  Afghanistan      AFG  2021-03-03                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# ...

# %%
vaccination.groupby('country');

# %%
vaccination.head(10)
# Out:
#        country iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG  2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG  2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG  2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG  2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG  2021-02-26                 NaN                NaN
# 5  Afghanistan      AFG  2021-02-27                 NaN                NaN
# 6  Afghanistan      AFG  2021-02-28              8200.0             8200.0
# 7  Afghanistan      AFG  2021-03-01                 NaN                NaN
# 8  Afghanistan      AFG  2021-03-02                 NaN                NaN
# 9  Afghanistan      AFG  2021-03-03                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# ...

# %%
vaccination.drop(['iso_code','total_vaccinations'],inplace=True,axis=1)

# %%
vaccination
# Out:
#            country        date  people_vaccinated  people_fully_vaccinated  \
# 0      Afghanistan  2021-02-22                0.0                      NaN
# 1      Afghanistan  2021-02-23                NaN                      NaN
# 2      Afghanistan  2021-02-24                NaN                      NaN
# 3      Afghanistan  2021-02-25                NaN                      NaN
# 4      Afghanistan  2021-02-26                NaN                      NaN
# ...            ...         ...                ...                      ...
# 86507     Zimbabwe  2022-03-25          4814582.0                3473523.0
# 86508     Zimbabwe  2022-03-26          4886242.0                3487962.0
# 86509     Zimbabwe  2022-03-27          4918147.0                3493763.0
# 86510     Zimbabwe  2022-03-28          4975433.0                3501493.0
# 86511     Zimbabwe  2022-03-29          5053114.0                3510256.0
#
#        daily_vaccinations_raw  daily_vaccinations  \
# ...

# %%
vaccination.drop(['daily_vaccinations_per_million','people_fully_vaccinated_per_hundred','vaccines','source_name'],inplace=True,axis=1)

# %%
vaccination
# Out:
#            country        date  people_vaccinated  people_fully_vaccinated  \
# 0      Afghanistan  2021-02-22                0.0                      NaN
# 1      Afghanistan  2021-02-23                NaN                      NaN
# 2      Afghanistan  2021-02-24                NaN                      NaN
# 3      Afghanistan  2021-02-25                NaN                      NaN
# 4      Afghanistan  2021-02-26                NaN                      NaN
# ...            ...         ...                ...                      ...
# 86507     Zimbabwe  2022-03-25          4814582.0                3473523.0
# 86508     Zimbabwe  2022-03-26          4886242.0                3487962.0
# 86509     Zimbabwe  2022-03-27          4918147.0                3493763.0
# 86510     Zimbabwe  2022-03-28          4975433.0                3501493.0
# 86511     Zimbabwe  2022-03-29          5053114.0                3510256.0
#
#        daily_vaccinations_raw  daily_vaccinations  \
# ...

# %%
vaccination.country.unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Andorra', 'Angola',
#        'Anguilla', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba',
#        'Australia', 'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain',
#        'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin',
#        'Bermuda', 'Bhutan', 'Bolivia', 'Bonaire Sint Eustatius and Saba',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'British Virgin Islands', 'Brunei', 'Bulgaria', 'Burkina Faso',
#        'Burundi', 'Cambodia', 'Cameroon', 'Canada', 'Cape Verde',
#        'Cayman Islands', 'Central African Republic', 'Chad', 'Chile',
#        'China', 'Colombia', 'Comoros', 'Congo', 'Cook Islands',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Curacao',
#        'Cyprus', 'Czechia', 'Democratic Republic of Congo', 'Denmark',
#        'Djibouti', 'Dominica', 'Dominican Republic', 'Ecuador', 'Egypt',
#        'El Salvador', 'England', 'Equatorial Guinea', 'Estonia',
# ...

# %%
vaccination.drop(['daily_vaccinations_raw','daily_vaccinations','total_vaccinations_per_hundred','people_vaccinated_per_hundred','source_website'],inplace=True,axis=1)

# %%
vaccination
# Out:
#            country        date  people_vaccinated  people_fully_vaccinated
# 0      Afghanistan  2021-02-22                0.0                      NaN
# 1      Afghanistan  2021-02-23                NaN                      NaN
# 2      Afghanistan  2021-02-24                NaN                      NaN
# 3      Afghanistan  2021-02-25                NaN                      NaN
# 4      Afghanistan  2021-02-26                NaN                      NaN
# ...            ...         ...                ...                      ...
# 86507     Zimbabwe  2022-03-25          4814582.0                3473523.0
# 86508     Zimbabwe  2022-03-26          4886242.0                3487962.0
# 86509     Zimbabwe  2022-03-27          4918147.0                3493763.0
# 86510     Zimbabwe  2022-03-28          4975433.0                3501493.0
# 86511     Zimbabwe  2022-03-29          5053114.0                3510256.0
#
# [86512 rows x 4 columns]

# %%
vaccination=vaccination.sort_values('people_vaccinated',ascending=False)

# %%
vaccination
# Out:
#         country        date  people_vaccinated  people_fully_vaccinated
# 16220     China  2022-03-24       1.275541e+09             1.240777e+09
# 16217     China  2022-03-21       1.274734e+09             1.240413e+09
# 16214     China  2022-03-18       1.273811e+09             1.239706e+09
# 16213     China  2022-03-17       1.273470e+09             1.239570e+09
# 16210     China  2022-03-14       1.272537e+09             1.239171e+09
# ...         ...         ...                ...                      ...
# 86307  Zimbabwe  2021-09-06                NaN                      NaN
# 86313  Zimbabwe  2021-09-12                NaN                      NaN
# 86318  Zimbabwe  2021-09-17                NaN                      NaN
# 86379  Zimbabwe  2021-11-17                NaN                      NaN
# 86422  Zimbabwe  2021-12-30                NaN                      NaN
#
# [86512 rows x 4 columns]

# %%
fv=vaccination.groupby('country').agg({'people_fully_vaccinated':'sum'})

# %%
percountry=vaccination.groupby('country').agg({'people_vaccinated':'sum'})

# %%
percountry
# Out:
#                    people_vaccinated
# country
# Afghanistan               98211047.0
# Albania                  149987489.0
# Algeria                  136020513.0
# Andorra                    1255700.0
# Angola                   249887443.0
# ...                              ...
# Wales                    886535676.0
# Wallis and Futuna           191870.0
# Yemen                      8551760.0
# Zambia                    30955954.0
# Zimbabwe                 914215909.0
#
# [223 rows x 1 columns]

# %%
percountry=percountry.sort_values('people_vaccinated')
# Out:
#                   people_vaccinated
# country
# Pitcairn               2.350000e+02
# Tokelau                2.889000e+03
# Niue                   6.074000e+03
# Falkland Islands       1.067100e+04
# Saint Helena           1.958000e+04
# ...                             ...
# China                  2.160637e+10
# Indonesia              3.492632e+10
# Brazil                 4.344773e+10
# United States          8.002542e+10
# India                  2.058197e+11
#
# [223 rows x 1 columns]

# %%
total_people_in_world_vaccinated=percountry.people_vaccinated.sum();

# %%
total_people_in_world_vaccinated
# Out:
# 731113482252.0

# %%
fv
# Out:
#                    people_fully_vaccinated
# country
# Afghanistan                     77716749.0
# Albania                        123869592.0
# Algeria                         98696382.0
# Andorra                           915747.0
# Angola                         124201062.0
# ...                                    ...
# Wales                          693174494.0
# Wallis and Futuna                 160774.0
# Yemen                            3769401.0
# Zambia                         123757924.0
# Zimbabwe                       662973726.0
#
# [223 rows x 1 columns]

# %%
fully_vaccination=fv.sort_values('people_fully_vaccinated')

# %%
fully_vaccinated
# Out:
# <bound method Series.sort_values of country
# Afghanistan           77716749.0
# Albania              123869592.0
# Algeria               98696382.0
# Andorra                 915747.0
# Angola               124201062.0
#                         ...
# Wales                693174494.0
# Wallis and Futuna       160774.0
# Yemen                  3769401.0
# Zambia               123757924.0
# Zimbabwe             662973726.0
# Name: people_fully_vaccinated, Length: 223, dtype: float64>

# %%
fully_vaccination
# Out:
#                   people_fully_vaccinated
# country
# Pitcairn                     1.130000e+02
# Tokelau                      9.680000e+02
# Falkland Islands             3.492000e+03
# Niue                         3.887000e+03
# Saint Helena                 4.653000e+03
# ...                                   ...
# Indonesia                    2.325724e+10
# Brazil                       3.027693e+10
# China                        3.526336e+10
# United States                6.663607e+10
# India                        1.164364e+11
#
# [223 rows x 1 columns]

# %%
total_people_in_world_fully_vaccinated=fully_vaccination.people_fully_vaccinated.sum()

# %%
total_people_in_world_fully_vaccinated
# Out:
# 548594310708.0

# %%
value=(548594310708/10000000000)

# %%
value
# Out:
# 54.8594310708

# %%
value2=731113482252/10000000000

# %%
value2
# Out:
# 73.1113482252

# %%
value=int(value)

# %%
value
# Out:
# 54

# %%
value2=int(value2)

# %%
value2
# Out:
# 73

# %%
type(value)
# Out:
# int

# %%
vaccines=[value,value2]
labels=['vaccinated','totally vaccinated']

# %%
vaccines
# Out:
# [54, 73]

# %%
plt.pie(vaccines,labels=labels)
# Out:
# ([<matplotlib.patches.Wedge at 0x1f09298aef0>,
# ...
#  [Text(0.25612836114443094, 1.0697655175866665, 'vaccinated'),
#   Text(-0.25612826098575375, -1.0697655415671294, 'totally vaccinated')])
